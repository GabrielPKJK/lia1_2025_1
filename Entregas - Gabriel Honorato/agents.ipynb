# %%
from dotenv import load_dotenv
import os
import google.generativeai as genai

# %%
# Carregar variável de ambiente
load_dotenv()
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
for model in genai.list_models():
    print(model.name)
# Out:
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# ...

# %%
# Função para criar agentes simulando comportamentos
def gerar_resposta_gemini(prompt):
    model = genai.GenerativeModel("models/gemini-1.5-flash")
    response = model.generate_content(prompt)
    return response.text.strip()

# %%
# Agente: Planejador de Dieta
def planejar_dieta(objetivo):
    prompt = f"""
    Você é um nutricionista especializado. Com base no objetivo "{objetivo}", crie um plano alimentar diário completo, incluindo:
    - Café da manhã
    - Almoço
    - Lanche(s)
    - Jantar
    O plano deve ser balanceado, adequado ao objetivo, e conter sugestões realistas.
    """
    return gerar_resposta_gemini(prompt)

# %%
# Agente: Calculadora de Macros
def calcular_macros(dieta):
    prompt = f"""
    Com base na dieta abaixo, calcule uma estimativa nutricional com:
    - Calorias totais
    - Quantidade aproximada de proteínas, carboidratos e gorduras (em gramas)
    
    DIETA:
    {dieta}
    """
    return gerar_resposta_gemini(prompt)

# %%
objetivo = "ganhar massa muscular"
dieta = planejar_dieta(objetivo)
macros = calcular_macros(dieta)

# %%
# Resultados
print("🍽️ Plano Alimentar:\n")
print(dieta)

print("\n📊 Estimativa Nutricional:\n")
print(macros)
# Out:
# 🍽️ Plano Alimentar:
#
# ## Plano Alimentar Diário para Ganho de Massa Muscular
#
# Este plano alimentar é uma sugestão e deve ser adaptado às suas necessidades individuais, nível de atividade física e preferências alimentares.  Consulte um nutricionista ou profissional de saúde antes de implementar qualquer mudança significativa na sua dieta, especialmente se você tiver alguma condição médica preexistente.  As quantidades devem ser ajustadas de acordo com seu peso, altura e gasto calórico diário.
#
# **Objetivo:** Ganho de Massa Muscular
#
# **Calorias Aproximadas:**  2800-3200 (Ajustar conforme necessário)  - Este valor é uma estimativa e precisa ser individualizado.
#
# **Macronutrientes (aproximados):** 40% Carboidratos, 35% Proteínas, 25% Gorduras.
#
#
# **Dia 1:**
#
# **Café da manhã (aprox. 600 calorias):**
#
# * 3 ovos inteiros mexidos com 1 colher de sopa de azeite extra virgem.
# ...
